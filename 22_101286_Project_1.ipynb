# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
upload= files.upload()
# Out:
#      <input type="file" id="files-68b4ae52-7c66-4734-928a-0faa72730229" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68b4ae52-7c66-4734-928a-0faa72730229">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
f= pd.read_csv('Untitled form 2.csv')

# %%
f
# Out:
#                      Timestamp  \
# 0    2024/03/02 7:26:22 pm EET
# 1    2024/03/02 7:28:05 pm EET
# 2    2024/03/02 7:31:31 pm EET
# 3    2024/03/02 7:32:48 pm EET
# 4    2024/03/02 8:21:19 pm EET
# 5    2024/03/02 8:21:24 pm EET
# 6    2024/03/02 8:25:10 pm EET
# 7    2024/03/02 8:26:40 pm EET
# 8    2024/03/02 8:27:59 pm EET
# 9    2024/03/02 8:28:07 pm EET
# 10   2024/03/02 8:28:11 pm EET
# 11   2024/03/02 8:52:28 pm EET
# 12   2024/03/02 8:52:36 pm EET
# 13  2024/03/02 10:09:59 pm EET
# 14  2024/03/02 10:45:41 pm EET
# 15  2024/03/02 11:15:32 pm EET
# 16  2024/03/02 11:36:52 pm EET
# 17   2024/03/03 8:43:09 am EET
# 18   2024/03/03 9:31:01 pm EET
# 19  2024/03/04 10:22:13 am EET
# 20  2024/03/04 11:11:36 am EET
# 21   2024/03/05 4:50:18 pm EET
# 22  2024/03/08 11:12:44 am EET
# 23   2024/03/08 1:48:08 pm EET
# 24   2024/03/10 6:52:10 pm EET
# 25   2024/03/10 6:52:36 pm EET
# 26   2024/03/10 6:52:59 pm EET
# 27   2024/03/10 6:53:14 pm EET
# 28   2024/03/10 6:53:43 pm EET
# ...

# %%
f.corr()
# Out:
# <ipython-input-9-caa569f9555e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   f.corr()
#                                                     2. On a scale of 1-5, how satisfied are you with your online shopping experience?
# 2. On a scale of 1-5, how satisfied are you wit...                                                1.0

# %%
print(f.columns)
# Out:
# Index(['Timestamp', '1.Have you shopped online in the past 6 months?',
#        '2. On a scale of 1-5, how satisfied are you with your online shopping experience?',
#        '3. How often do you shop online?',
#        '4. What factors do you consider when choosing an online shopping platform?',
#        '5. How do you typically pay for your online purchases?',
#        '6. How often do you return or exchange items purchased online?'],
#       dtype='object')

# %%
Scale_column = f['2. On a scale of 1-5, how satisfied are you with your online shopping experience?']

# Calculate the mean
mean_Scale = Scale_column.mean()
print("Mean of Scale_column: ", mean_Scale)

# Calculate the median
median_Scale = Scale_column.median()
print("Median of Scale_column:", median_Scale)

# Calculate the mode
mode_Scale = Scale_column.mode()[0]
print("Mode of Scale_column:", mode_Scale)
# Out:
# Mean of Scale_column:  3.5
# Median of Scale_column: 4.0
# Mode of Scale_column: 4
